# %% [markdown]
# *   **Material de estudo Alura**
# *   **Exercicios de fixação do curso data science alura**

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
tmdb = pd.read_csv("tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
contagem_de_lingua = tmdb['original_language'].value_counts().to_frame().reset_index()
contagem_de_lingua.columns = ['original_language','total']
contagem_de_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                de     27
# 4                zh     27

# %%
sns.barplot(x = 'original_language', y ="total",data = contagem_de_lingua)

# %%
sns.catplot(x = 'original_language',kind = 'count' ,data = tmdb)

# %%
plt.pie(contagem_de_lingua['total'],labels = contagem_de_lingua['original_language'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8dfa5670d0>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'de'),
#   Text(1.0773191105706255, -0.22222406260195313, 'zh'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ko'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ru'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'nl'),
#   Text(1.0990363161210686, -0.04603450713357274, 'fa'),
# ...

# %%
total_por_lingua = tmdb['original_language'].value_counts()
total_geral = total_por_lingua.sum()
total_ingles = total_por_lingua.loc["en"]
total_resto = total_geral - total_ingles

# %%
dados = {
    'lingua' : ['ingles', 'outros'],
    'total'  : [total_ingles, total_resto]

  
    }

# %%
dados = pd.DataFrame(dados)

# %%
sns.barplot(x = 'lingua',y='total', data = dados)

# %%
eae =tmdb.query("original_language != 'en'").original_language.value_counts()
eae
# Out:
# fr    70
# es    32
# de    27
# zh    27
# hi    19
# ja    16
# it    14
# cn    12
# ko    11
# ru    11
# pt     9
# da     7
# sv     5
# nl     4
# fa     4
# he     3
# th     3
# id     2
# cs     2
# ta     2
# ro     2
# ar     2
# el     1
# hu     1
# ky     1
# is     1
# no     1
# xx     1
# nb     1
# te     1
# af     1
# tr     1
# ps     1
# sl     1
# pl     1
# vi     1
# Name: original_language, dtype: int64

# %%
total_por_lingua_de_outros_filmes =tmdb.query("original_language != 'en'")
total_por_lingua_de_outros_filmes
# Out:
#         budget  ... vote_count
# 97    15000000  ...        143
# 235   97250400  ...        471
# 317   94000000  ...        187
# 474          0  ...         47
# 492    8000000  ...          9
# ...        ...  ...        ...
# 4739         0  ...          1
# 4751         0  ...          2
# 4790         0  ...         17
# 4792     20000  ...         63
# 4798    220000  ...        238
#
# [298 rows x 20 columns]

# %%
 sns.catplot( x ="original_language",kind='count',data = total_por_lingua_de_outros_filmes,aspect=3, order = eae.index,
            palette='rocket' )

# %%
import seaborn as sns
sns.set(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %%
filmes = pd.read_csv('movies.csv')
notas = pd.read_csv('ratings.csv')
notas.head(2)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247

# %%
filmes.head(2)
notas_toy_story = notas.query('movieId==1')
notas_toy_jumanji = notas.query('movieId==2')
print(len(notas_toy_story),len(notas_toy_jumanji))
# Out:
# 215 110

# %%
print('notas medias do toy story %.2f' % notas_toy_story.rating.mean())
print('notas medias do jumanji %.2f' % notas_toy_jumanji.rating.mean())
# Out:
# notas medias do toy story 3.92
# notas medias do jumanji 3.43

# %%
import numpy as np
sns.boxplot(x=notas_toy_jumanji.rating)

# %%
plt.boxplot([notas_toy_story.rating,notas_toy_jumanji.rating])
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# {'boxes': [<matplotlib.lines.Line2D at 0x7f8df316cb90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f8df3172c10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8df317de50>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8df317d850>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f8df31721d0>,
# ...
#   <matplotlib.lines.Line2D at 0x7f8df3184dd0>]}

# %%
sns.boxplot(x='movieId', y='rating', data = notas.query('movieId in [1,2,3,4,5]'))

# %%
sns.boxplot(notas_toy_story.rating)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
